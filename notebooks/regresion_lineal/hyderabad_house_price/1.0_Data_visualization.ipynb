# %% [markdown]
# # Hyderabad House Price Data Visualization

# %%
import pandas as pd

house_prices_ds = pd.read_csv('../../../datasets/raw/hyderabad_house_price_with_nullables.csv')

samples = house_prices_ds.shape[0]
dimensions = house_prices_ds.shape[1]
numeric_cols = house_prices_ds.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_cols = house_prices_ds.select_dtypes(include=["object", "category"]).columns.tolist()

print(f"Samples: {samples}")
print(f"Dimensions (Label + features): {dimensions}")
print(f"Categoricals: {len(categorical_cols)}")
print(f"Numerics: {len(numeric_cols)}")
print("Numeric features: ", numeric_cols)
print("Categoricals features: ", categorical_cols)

house_prices_ds.info()
# Out:
# Samples: 2523
# Dimensions (Label + features): 40
# Categoricals: 1
# Numerics: 39
# Numeric features:  ['Price', 'Area', 'No. of Bedrooms', 'Resale', 'MaintenanceStaff', 'Gymnasium', 'SwimmingPool', 'LandscapedGardens', 'JoggingTrack', 'RainWaterHarvesting', 'IndoorGames', 'ShoppingMall', 'Intercom', 'SportsFacility', 'ATM', 'ClubHouse', 'School', '24X7Security', 'PowerBackup', 'CarParking', 'StaffQuarter', 'Cafeteria', 'MultipurposeRoom', 'Hospital', 'WashingMachine', 'Gasconnection', 'AC', 'Wifi', "Children'splayarea", 'LiftAvailable', 'BED', 'VaastuCompliant', 'Microwave', 'GolfCourse', 'TV', 'DiningTable', 'Sofa', 'Wardrobe', 'Refrigerator']
# Categoricals features:  ['Location']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2523 entries, 0 to 2522
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                2523 non-null   int64
#  1   Area                 2522 non-null   float64
#  2   Location             2523 non-null   object
#  3   No. of Bedrooms      2522 non-null   float64
#  4   Resale               2523 non-null   int64
#  5   MaintenanceStaff     2523 non-null   int64
#  6   Gymnasium            2523 non-null   int64
#  7   SwimmingPool         2523 non-null   int64
#  8   LandscapedGardens    2523 non-null   int64
#  9   JoggingTrack         2523 non-null   int64
#  10  RainWaterHarvesting  2523 non-null   int64
#  11  IndoorGames          2523 non-null   int64
#  12  ShoppingMall         2523 non-null   int64
#  13  Intercom             2523 non-null   int64
#  14  SportsFacility       2523 non-null   int64
#  15  ATM                  2523 non-null   int64
#  16  ClubHouse            2523 non-null   int64
#  17  School               2523 non-null   int64
#  18  24X7Security         2522 non-null   float64
#  19  PowerBackup          2523 non-null   int64
#  20  CarParking           2523 non-null   int64
#  21  StaffQuarter         2523 non-null   int64
#  22  Cafeteria            2523 non-null   int64
#  23  MultipurposeRoom     2523 non-null   int64
#  24  Hospital             2523 non-null   int64
#  25  WashingMachine       2523 non-null   int64
#  26  Gasconnection        2523 non-null   int64
#  27  AC                   2523 non-null   int64
#  28  Wifi                 2523 non-null   int64
#  29  Children'splayarea   2523 non-null   int64
#  30  LiftAvailable        2523 non-null   int64
#  31  BED                  2523 non-null   int64
#  32  VaastuCompliant      2523 non-null   int64
#  33  Microwave            2523 non-null   int64
#  34  GolfCourse           2523 non-null   int64
#  35  TV                   2523 non-null   int64
#  36  DiningTable          2523 non-null   int64
#  37  Sofa                 2523 non-null   int64
#  38  Wardrobe             2523 non-null   int64
#  39  Refrigerator         2521 non-null   float64
# dtypes: float64(4), int64(35), object(1)
# memory usage: 788.6+ KB

# %% [markdown]
# ## Descriptive statistics

# %%
# Descriptive statistics
house_prices_ds.describe()
# Out:
#               Price         Area  No. of Bedrooms       Resale  \
# count  2.523000e+03  2522.000000      2522.000000  2523.000000
# mean   9.811845e+06  1644.076527         2.623711     0.227507
# std    8.771288e+06   745.885388         0.687020     0.419306
# min    2.000000e+06   500.000000         1.000000     0.000000
# 25%    4.760000e+06  1160.000000         2.000000     0.000000
# 50%    7.753000e+06  1500.000000         3.000000     0.000000
# 75%    1.090000e+07  1825.000000         3.000000     0.000000
# max    1.650000e+08  9400.000000         8.000000     1.000000
#
#        MaintenanceStaff    Gymnasium  SwimmingPool  LandscapedGardens  \
# count       2523.000000  2523.000000   2523.000000        2523.000000
# mean           0.426080     0.753072      0.722949           0.632580
# std            1.660399     1.642656      1.647017           1.656746
# min            0.000000     0.000000      0.000000           0.000000
# 25%            0.000000     0.000000      0.000000           0.000000
# 50%            0.000000     0.000000      0.000000           0.000000
# 75%            0.000000     1.000000      1.000000           1.000000
# max            9.000000     9.000000      9.000000           9.000000
#
#        JoggingTrack  RainWaterHarvesting  ...  LiftAvailable          BED  \
# count   2523.000000          2523.000000  ...    2523.000000  2523.000000
# mean       0.573524             0.619501  ...       0.988506     0.373761
# std        1.660417             1.657741  ...       1.588603     1.657241
# min        0.000000             0.000000  ...       0.000000     0.000000
# 25%        0.000000             0.000000  ...       0.000000     0.000000
# 50%        0.000000             0.000000  ...       1.000000     0.000000
# 75%        1.000000             1.000000  ...       1.000000     0.000000
# max        9.000000             9.000000  ...       9.000000     9.000000
#
#        VaastuCompliant    Microwave   GolfCourse           TV  DiningTable  \
# count      2523.000000  2523.000000  2523.000000  2523.000000  2523.000000
# mean          0.620293     0.356322     0.343639     0.334919     0.347998
# std           1.657684     1.655820     1.654670     1.653822     1.655076
# min           0.000000     0.000000     0.000000     0.000000     0.000000
# 25%           0.000000     0.000000     0.000000     0.000000     0.000000
# 50%           0.000000     0.000000     0.000000     0.000000     0.000000
# 75%           1.000000     0.000000     0.000000     0.000000     0.000000
# max           9.000000     9.000000     9.000000     9.000000     9.000000
#
#               Sofa     Wardrobe  Refrigerator
# count  2523.000000  2523.000000   2521.000000
# mean      0.355925     0.354736      0.331614
# std       1.655785     1.655681      1.636728
# min       0.000000     0.000000      0.000000
# 25%       0.000000     0.000000      0.000000
# 50%       0.000000     0.000000      0.000000
# 75%       0.000000     0.000000      0.000000
# max       9.000000     9.000000      9.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# ## 1. Detention of missing values

# %%
# Summary of missing values
print("Total Missing values:", house_prices_ds.isnull().sum().sum())

print("1. Missing Values by columns:")
house_prices_ds.isnull().sum()
# Out:
# Total Missing values: 5
# 1. Missing Values by columns:
# Price                  0
# Area                   1
# Location               0
# No. of Bedrooms        1
# Resale                 0
# MaintenanceStaff       0
# Gymnasium              0
# SwimmingPool           0
# LandscapedGardens      0
# JoggingTrack           0
# RainWaterHarvesting    0
# IndoorGames            0
# ShoppingMall           0
# Intercom               0
# SportsFacility         0
# ATM                    0
# ClubHouse              0
# School                 0
# 24X7Security           1
# PowerBackup            0
# CarParking             0
# StaffQuarter           0
# Cafeteria              0
# MultipurposeRoom       0
# Hospital               0
# WashingMachine         0
# Gasconnection          0
# AC                     0
# Wifi                   0
# Children'splayarea     0
# LiftAvailable          0
# BED                    0
# VaastuCompliant        0
# Microwave              0
# GolfCourse             0
# TV                     0
# DiningTable            0
# Sofa                   0
# Wardrobe               0
# Refrigerator           2
# dtype: int64

# %% [markdown]
# ## Outiers values (percetiles)

# %%
import seaborn as sns
import matplotlib.pyplot as plt


for col in house_prices_ds.select_dtypes(include=["int64", "float64"]).columns:
    sns.boxplot(x=house_prices_ds[col])
    plt.title(f"Boxplot de {col}")
    plt.show()

# %% [markdown]
# ## Distribution of individual variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Seleccionar columnas numéricas
numeric_cols = house_prices_ds.select_dtypes(include=["int64","float64"]).columns

# Definir layout de subplots
n_cols = 3  # cantidad de columnas de subplots
n_rows = int(np.ceil(len(numeric_cols) / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows))
axes = axes.flatten()  # lo convertimos a 1D para iterar fácil

# Crear histogramas en cada subplot
for i, col in enumerate(numeric_cols):
    sns.histplot(data=house_prices_ds, x=col, bins=10, ax=axes[i], kde=True)
    axes[i].set_title(f"Distribución de {col}")

# Eliminar ejes vacíos si sobran
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# house_prices_ds.info()

import pandas as pd
from pandas.api.types import (is_numeric_dtype, is_categorical_dtype, is_object_dtype, is_bool_dtype)


df_info = house_prices_ds.apply(
    lambda s: pd.Series({
        "type": s.dtype.name,
        "nullables": s.isna().sum(),
        "nullables_procentage": round(s.isna().mean() * 100, 2),
        "is_numeric": is_numeric_dtype(s),
        "is_categorical": (
            is_object_dtype(s) or
            is_categorical_dtype(s) or
            is_bool_dtype(s)
        )
    })
)
# Out:
# C:\Users\luis.bolanoss\AppData\Local\Temp\ipykernel_5460\1278709319.py:15: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   is_categorical_dtype(s) or

# %% [markdown]
# ## Correlation Matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = house_prices_ds.copy()
numeric_ds = df.select_dtypes(include=["int64", "float64"])

# Find correlation between variables
# La correlación es una medida estadística que indica qué tan fuerte y en qué dirección se relacionan dos variables.
# Si aumenta una variable y también aumenta la otra, decimos que hay correlación positiva.
# Si aumenta una variable y la otra disminuye, hablamos de correlación negativa.
# Si no hay un patrón claro, la correlación es cercana a 0 (sin relación lineal).
corr = numeric_ds.corr()
print(corr)

# HitMap
plt.figure(figsize=(20,16))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()
# Out:
#                         Price      Area  No. of Bedrooms    Resale  \
